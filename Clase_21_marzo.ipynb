# %% [markdown]
# # Manejo de Excepciones
#
# Las funciones a usar son
#
#
# ```
# # try:
#   bloque de condición
#   except:
#   bloque de excepciones
#
# ```
# Vamos a usar una función que se llama `assert`.

# %%
def division(a,b):
  return a/b

# %%
division(1,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-b1a4f064b07e> in <cell line: 0>()
# ----> 1 division(1,0)
#
# <ipython-input-2-5117be529140> in division(a, b)
#       1 def division(a,b):
# ----> 2   return a/b
#
# ZeroDivisionError: division by zero

# %%
# Ejemplo 1
a = 5

b = 0

try:
  x = a/b
except ZeroDivisionError:
  print("Alvaro, no dividas entre cero")
# Out:
# Alvaro, no dividas entre cero

# %%
# Ejemplo 2

try:
  d = 2 + "Ceci"

except TypeError:
  print("¡Cuidado! La suma debe ser sobre los mismos objetos")
# Out:
# ¡Cuidado! La suma debe ser sobre los mismos objetos

# %%
# Vamos a redefinir nuestra definición de división

def division(a,b):
  try:
    c = a/b
    print("Resultado de la división", c)
  except ZeroDivisionError:
    print("Jaume, no dividas entre cero")
  except TypeError:
    print("No dividas un número entre un string")

# %%
division(5,0)
# Out:
# Jaume, no dividas entre cero

# %%
division(2,"Ceci")
# Out:
# No dividas un número entre un string

# %%
division(2,3)
# Out:
# Resultado de la división 0.6666666666666666

# %% [markdown]
# ## La función `assert`

# %%
assert(1==2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-91d16dafa3fa> in <cell line: 0>()
# ----> 1 assert(1==2)
#
# AssertionError:

# %%
def calcular_media(L):
  z = sum(L)/len(L)
  return z

# %%
calcular_media([17,19,25.0,-2,])
# Out:
# 14.75

# %%
assert(calcular_media([17,19,25.0,-2,])==14.75)
